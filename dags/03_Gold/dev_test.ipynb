# %%
import pandas as pd 
import requests

# %%
api_url = "https://fantasy.premierleague.com/api/bootstrap-static/"
try:
    response = requests.get(api_url)
    response.raise_for_status()
    data = response.json()
except requests.RequestException as e:
    logging.error(f"❌ Error fetching data from API: {e}")
    raise

# %%
data.key()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data.key()
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
data
# Out:
# {'chips': [{'id': 1,
#    'name': 'wildcard',
#    'number': 1,
#    'start_event': 2,
#    'stop_event': 19,
#    'chip_type': 'transfer',
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None}},
#   {'id': 2,
#    'name': 'wildcard',
#    'number': 1,
#    'start_event': 20,
#    'stop_event': 38,
#    'chip_type': 'transfer',
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None}},
#   {'id': 3,
#    'name': 'freehit',
#    'number': 1,
#    'start_event': 2,
#    'stop_event': 38,
#    'chip_type': 'transfer',
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None}},
#   {'id': 4,
#    'name': 'bboost',
#    'number': 1,
#    'start_event': 1,
#    'stop_event': 38,
#    'chip_type': 'team',
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None}},
#   {'id': 5,
#    'name': '3xc',
#    'number': 1,
#    'start_event': 1,
#    'stop_event': 38,
#    'chip_type': 'team',
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None}},
#   {'id': 6,
#    'name': 'manager',
#    'number': 1,
#    'start_event': 24,
#    'stop_event': 38,
#    'chip_type': 'transfer',
#    'overrides': {'rules': {'squad_squadsize': 16},
#     'scoring': {},
#     'element_types': [{'id': 5,
#       'plural_name': 'Managers',
#       'plural_name_short': 'MNG',
#       'singular_name': 'Manager',
#       'singular_name_short': 'MNG',
#       'squad_select': 1,
#       'squad_min_select': None,
#       'squad_max_select': None,
#       'squad_min_play': 0,
#       'squad_max_play': 0,
#       'ui_shirt_specific': True,
#       'sub_positions_locked': [16],
#       'element_count': 20}],
#     'pick_multiplier': None}}],
#  'events': [{'id': 1,
#    'name': 'Gameweek 1',
#    'deadline_time': '2024-08-16T17:30:00Z',
#    'release_time': None,
#    'average_entry_score': 57,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 3546234,
#    'deadline_time_epoch': 1723829400,
#    'deadline_time_game_offset': 0,
#    'highest_score': 127,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 8597356,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974},
#     {'chip_name': '3xc', 'num_played': 221430}],
#    'most_selected': 401,
#    'most_transferred_in': 27,
#    'top_element': 328,
#    'top_element_info': {'id': 328, 'points': 14},
#    'transfers_made': 0,
#    'most_captained': 351,
#    'most_vice_captained': 351},
#   {'id': 2,
#    'name': 'Gameweek 2',
#    'deadline_time': '2024-08-24T10:00:00Z',
#    'release_time': None,
#    'average_entry_score': 69,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 9442126,
#    'deadline_time_epoch': 1724493600,
#    'deadline_time_game_offset': 0,
#    'highest_score': 154,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 9543353,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 118782},
#     {'chip_name': 'freehit', 'num_played': 102788},
#     {'chip_name': 'wildcard', 'num_played': 217521},
#     {'chip_name': '3xc', 'num_played': 612384}],
#    'most_selected': 401,
#    'most_transferred_in': 594,
#    'top_element': 177,
#    'top_element_info': {'id': 177, 'points': 20},
#    'transfers_made': 13364453,
#    'most_captained': 351,
#    'most_vice_captained': 401},
#   {'id': 3,
#    'name': 'Gameweek 3',
#    'deadline_time': '2024-08-31T10:00:00Z',
#    'release_time': None,
#    'average_entry_score': 64,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 430195,
#    'deadline_time_epoch': 1725098400,
#    'deadline_time_game_offset': 0,
#    'highest_score': 130,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 9912161,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 87334},
#     {'chip_name': 'freehit', 'num_played': 140192},
#     {'chip_name': 'wildcard', 'num_played': 656652},
#     {'chip_name': '3xc', 'num_played': 186907}],
#    'most_selected': 351,
#    'most_transferred_in': 177,
#    'top_element': 328,
#    'top_element_info': {'id': 328, 'points': 17},
#    'transfers_made': 23723836,
#    'most_captained': 351,
#    'most_vice_captained': 328},
#   {'id': 4,
#    'name': 'Gameweek 4',
#    'deadline_time': '2024-09-14T10:00:00Z',
#    'release_time': None,
#    'average_entry_score': 51,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 3560750,
#    'deadline_time_epoch': 1726308000,
#    'deadline_time_game_offset': 0,
#    'highest_score': 120,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10178753,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 83637},
#     {'chip_name': 'freehit', 'num_played': 125561},
#     {'chip_name': 'wildcard', 'num_played': 940783},
#     {'chip_name': '3xc', 'num_played': 199688}],
#    'most_selected': 351,
#    'most_transferred_in': 129,
#    'top_element': 185,
#    'top_element_info': {'id': 185, 'points': 15},
#    'transfers_made': 25930392,
#    'most_captained': 351,
#    'most_vice_captained': 328},
#   {'id': 5,
#    'name': 'Gameweek 5',
#    'deadline_time': '2024-09-21T10:00:00Z',
#    'release_time': None,
#    'average_entry_score': 58,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 1773336,
#    'deadline_time_epoch': 1726912800,
#    'deadline_time_game_offset': 0,
#    'highest_score': 131,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10279610,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 66447},
#     {'chip_name': 'freehit', 'num_played': 79498},
#     {'chip_name': 'wildcard', 'num_played': 311710},
#     {'chip_name': '3xc', 'num_played': 71288}],
#    'most_selected': 351,
#    'most_transferred_in': 58,
#    'top_element': 180,
#    'top_element_info': {'id': 180, 'points': 16},
#    'transfers_made': 13036058,
#    'most_captained': 351,
#    'most_vice_captained': 351},
#   {'id': 6,
#    'name': 'Gameweek 6',
#    'deadline_time': '2024-09-28T10:00:00Z',
#    'release_time': None,
#    'average_entry_score': 50,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 7479996,
#    'deadline_time_epoch': 1727517600,
#    'deadline_time_game_offset': 0,
#    'highest_score': 142,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10369689,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 62665},
#     {'chip_name': 'freehit', 'num_played': 84229},
#     {'chip_name': 'wildcard', 'num_played': 663489},
#     {'chip_name': '3xc', 'num_played': 83406}],
#    'most_selected': 351,
#    'most_transferred_in': 327,
#    'top_element': 182,
#    'top_element_info': {'id': 182, 'points': 25},
#    'transfers_made': 21036913,
#    'most_captained': 351,
#    'most_vice_captained': 328},
#   {'id': 7,
#    'name': 'Gameweek 7',
#    'deadline_time': '2024-10-05T10:00:00Z',
#    'release_time': None,
#    'average_entry_score': 46,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 759474,
#    'deadline_time_epoch': 1728122400,
#    'deadline_time_game_offset': 0,
#    'highest_score': 130,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10466714,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 54778},
#     {'chip_name': 'freehit', 'num_played': 81146},
#     {'chip_name': 'wildcard', 'num_played': 308835},
#     {'chip_name': '3xc', 'num_played': 140205}],
#    'most_selected': 351,
#    'most_transferred_in': 182,
#    'top_element': 512,
#    'top_element_info': {'id': 512, 'points': 18},
#    'transfers_made': 14594461,
#    'most_captained': 351,
#    'most_vice_captained': 328},
#   {'id': 8,
#    'name': 'Gameweek 8',
#    'deadline_time': '2024-10-19T10:00:00Z',
#    'release_time': None,
#    'average_entry_score': 36,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 5482232,
#    'deadline_time_epoch': 1729332000,
#    'deadline_time_game_offset': 0,
#    'highest_score': 98,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10552679,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 65446},
#     {'chip_name': 'freehit', 'num_played': 64301},
#     {'chip_name': 'wildcard', 'num_played': 221063},
#     {'chip_name': '3xc', 'num_played': 111602}],
#    'most_selected': 351,
#    'most_transferred_in': 491,
#    'top_element': 228,
#    'top_element_info': {'id': 228, 'points': 14},
#    'transfers_made': 11911632,
#    'most_captained': 351,
#    'most_vice_captained': 328},
#   {'id': 9,
#    'name': 'Gameweek 9',
#    'deadline_time': '2024-10-25T17:30:00Z',
#    'release_time': None,
#    'average_entry_score': 54,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 2039494,
#    'deadline_time_epoch': 1729877400,
#    'deadline_time_game_offset': 0,
#    'highest_score': 117,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10594653,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 51136},
#     {'chip_name': 'freehit', 'num_played': 71811},
#     {'chip_name': 'wildcard', 'num_played': 158486},
#     {'chip_name': '3xc', 'num_played': 330035}],
#    'most_selected': 351,
#    'most_transferred_in': 99,
#    'top_element': 99,
#    'top_element_info': {'id': 99, 'points': 15},
#    'transfers_made': 10882045,
#    'most_captained': 351,
#    'most_vice_captained': 182},
#   {'id': 10,
#    'name': 'Gameweek 10',
#    'deadline_time': '2024-11-02T11:00:00Z',
#    'release_time': None,
#    'average_entry_score': 39,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 1689659,
#    'deadline_time_epoch': 1730545200,
#    'deadline_time_game_offset': 0,
#    'highest_score': 111,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10648436,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 75823},
#     {'chip_name': 'freehit', 'num_played': 70729},
#     {'chip_name': 'wildcard', 'num_played': 162964},
#     {'chip_name': '3xc', 'num_played': 85359}],
#    'most_selected': 351,
#    'most_transferred_in': 99,
#    'top_element': 82,
#    'top_element_info': {'id': 82, 'points': 16},
#    'transfers_made': 11763382,
#    'most_captained': 351,
#    'most_vice_captained': 182},
#   {'id': 11,
#    'name': 'Gameweek 11',
#    'deadline_time': '2024-11-09T13:30:00Z',
#    'release_time': None,
#    'average_entry_score': 49,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 10668888,
#    'deadline_time_epoch': 1731159000,
#    'deadline_time_game_offset': 0,
#    'highest_score': 136,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10693676,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 79875},
#     {'chip_name': 'freehit', 'num_played': 84689},
#     {'chip_name': 'wildcard', 'num_played': 138253},
#     {'chip_name': '3xc', 'num_played': 52784}],
#    'most_selected': 351,
#    'most_transferred_in': 447,
#    'top_element': 366,
#    'top_element_info': {'id': 366, 'points': 17},
#    'transfers_made': 11631910,
#    'most_captained': 351,
#    'most_vice_captained': 328},
#   {'id': 12,
#    'name': 'Gameweek 12',
#    'deadline_time': '2024-11-23T11:00:00Z',
#    'release_time': None,
#    'average_entry_score': 49,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 7440806,
#    'deadline_time_epoch': 1732359600,
#    'deadline_time_game_offset': 0,
#    'highest_score': 128,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10751495,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 59590},
#     {'chip_name': 'freehit', 'num_played': 89443},
#     {'chip_name': 'wildcard', 'num_played': 252772},
#     {'chip_name': '3xc', 'num_played': 111773}],
#    'most_selected': 351,
#    'most_transferred_in': 366,
#    'top_element': 541,
#    'top_element_info': {'id': 541, 'points': 16},
#    'transfers_made': 13315756,
#    'most_captained': 351,
#    'most_vice_captained': 182},
#   {'id': 13,
#    'name': 'Gameweek 13',
#    'deadline_time': '2024-11-29T18:30:00Z',
#    'release_time': None,
#    'average_entry_score': 60,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 1929511,
#    'deadline_time_epoch': 1732905000,
#    'deadline_time_game_offset': 0,
#    'highest_score': 144,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10786063,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 57138},
#     {'chip_name': 'freehit', 'num_played': 71881},
#     {'chip_name': 'wildcard', 'num_played': 144095},
#     {'chip_name': '3xc', 'num_played': 44722}],
#    'most_selected': 328,
#    'most_transferred_in': 541,
#    'top_element': 106,
#    'top_element_info': {'id': 106, 'points': 23},
#    'transfers_made': 10651205,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 14,
#    'name': 'Gameweek 14',
#    'deadline_time': '2024-12-03T18:00:00Z',
#    'release_time': None,
#    'average_entry_score': 58,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 2964307,
#    'deadline_time_epoch': 1733248800,
#    'deadline_time_game_offset': 0,
#    'highest_score': 132,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10821193,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 58057},
#     {'chip_name': 'freehit', 'num_played': 60749},
#     {'chip_name': 'wildcard', 'num_played': 141083},
#     {'chip_name': '3xc', 'num_played': 80792}],
#    'most_selected': 328,
#    'most_transferred_in': 180,
#    'top_element': 328,
#    'top_element_info': {'id': 328, 'points': 18},
#    'transfers_made': 10912413,
#    'most_captained': 351,
#    'most_vice_captained': 328},
#   {'id': 15,
#    'name': 'Gameweek 15',
#    'deadline_time': '2024-12-07T11:00:00Z',
#    'release_time': None,
#    'average_entry_score': 50,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 7399737,
#    'deadline_time_epoch': 1733569200,
#    'deadline_time_game_offset': 0,
#    'highest_score': 119,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10854873,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 46111},
#     {'chip_name': 'freehit', 'num_played': 102956},
#     {'chip_name': 'wildcard', 'num_played': 98439},
#     {'chip_name': '3xc', 'num_played': 72929}],
#    'most_selected': 182,
#    'most_transferred_in': 17,
#    'top_element': 182,
#    'top_element_info': {'id': 182, 'points': 18},
#    'transfers_made': 10409133,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 16,
#    'name': 'Gameweek 16',
#    'deadline_time': '2024-12-14T13:30:00Z',
#    'release_time': None,
#    'average_entry_score': 47,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 5142221,
#    'deadline_time_epoch': 1734183000,
#    'deadline_time_game_offset': 0,
#    'highest_score': 119,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10906389,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 72296},
#     {'chip_name': 'freehit', 'num_played': 56121},
#     {'chip_name': 'wildcard', 'num_played': 120570},
#     {'chip_name': '3xc', 'num_played': 100883}],
#    'most_selected': 328,
#    'most_transferred_in': 401,
#    'top_element': 585,
#    'top_element_info': {'id': 585, 'points': 17},
#    'transfers_made': 10586275,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 17,
#    'name': 'Gameweek 17',
#    'deadline_time': '2024-12-21T11:00:00Z',
#    'release_time': None,
#    'average_entry_score': 60,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 4917384,
#    'deadline_time_epoch': 1734778800,
#    'deadline_time_game_offset': 0,
#    'highest_score': 151,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10946145,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 80801},
#     {'chip_name': 'freehit', 'num_played': 59644},
#     {'chip_name': 'wildcard', 'num_played': 136974},
#     {'chip_name': '3xc', 'num_played': 55811}],
#    'most_selected': 182,
#    'most_transferred_in': 364,
#    'top_element': 328,
#    'top_element_info': {'id': 328, 'points': 21},
#    'transfers_made': 10405730,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 18,
#    'name': 'Gameweek 18',
#    'deadline_time': '2024-12-26T11:00:00Z',
#    'release_time': None,
#    'average_entry_score': 51,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 2701866,
#    'deadline_time_epoch': 1735210800,
#    'deadline_time_game_offset': 0,
#    'highest_score': 118,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 10984600,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 97727},
#     {'chip_name': 'freehit', 'num_played': 83399},
#     {'chip_name': 'wildcard', 'num_played': 374001},
#     {'chip_name': '3xc', 'num_played': 202796}],
#    'most_selected': 328,
#    'most_transferred_in': 401,
#    'top_element': 403,
#    'top_element_info': {'id': 403, 'points': 13},
#    'transfers_made': 13895381,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 19,
#    'name': 'Gameweek 19',
#    'deadline_time': '2024-12-29T13:00:00Z',
#    'release_time': None,
#    'average_entry_score': 66,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 3191421,
#    'deadline_time_epoch': 1735477200,
#    'deadline_time_game_offset': 0,
#    'highest_score': 142,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 11011909,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 83841},
#     {'chip_name': 'freehit', 'num_played': 62471},
#     {'chip_name': 'wildcard', 'num_played': 427439},
#     {'chip_name': '3xc', 'num_played': 67924}],
#    'most_selected': 182,
#    'most_transferred_in': 401,
#    'top_element': 328,
#    'top_element_info': {'id': 328, 'points': 16},
#    'transfers_made': 10957444,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 20,
#    'name': 'Gameweek 20',
#    'deadline_time': '2025-01-04T11:00:00Z',
#    'release_time': None,
#    'average_entry_score': 60,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 1247541,
#    'deadline_time_epoch': 1735988400,
#    'deadline_time_game_offset': 0,
#    'highest_score': 136,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 11058766,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 73435},
#     {'chip_name': 'freehit', 'num_played': 67748},
#     {'chip_name': 'wildcard', 'num_played': 412768},
#     {'chip_name': '3xc', 'num_played': 141464}],
#    'most_selected': 328,
#    'most_transferred_in': 447,
#    'top_element': 99,
#    'top_element_info': {'id': 99, 'points': 19},
#    'transfers_made': 13978697,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 21,
#    'name': 'Gameweek 21',
#    'deadline_time': '2025-01-14T18:00:00Z',
#    'release_time': None,
#    'average_entry_score': 55,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 434390,
#    'deadline_time_epoch': 1736877600,
#    'deadline_time_game_offset': 0,
#    'highest_score': 148,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 11114287,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 89332},
#     {'chip_name': 'freehit', 'num_played': 63224},
#     {'chip_name': 'wildcard', 'num_played': 286969},
#     {'chip_name': '3xc', 'num_played': 51092}],
#    'most_selected': 328,
#    'most_transferred_in': 398,
#    'top_element': 364,
#    'top_element_info': {'id': 364, 'points': 20},
#    'transfers_made': 11543203,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 22,
#    'name': 'Gameweek 22',
#    'deadline_time': '2025-01-18T11:00:00Z',
#    'release_time': None,
#    'average_entry_score': 46,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 2700271,
#    'deadline_time_epoch': 1737198000,
#    'deadline_time_game_offset': 0,
#    'highest_score': 128,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 11136058,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 102686},
#     {'chip_name': 'freehit', 'num_played': 35776},
#     {'chip_name': 'wildcard', 'num_played': 166215},
#     {'chip_name': '3xc', 'num_played': 45688}],
#    'most_selected': 328,
#    'most_transferred_in': 447,
#    'top_element': 71,
#    'top_element_info': {'id': 71, 'points': 22},
#    'transfers_made': 8284410,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 23,
#    'name': 'Gameweek 23',
#    'deadline_time': '2025-01-25T13:30:00Z',
#    'release_time': None,
#    'average_entry_score': 59,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 11007664,
#    'deadline_time_epoch': 1737811800,
#    'deadline_time_game_offset': 0,
#    'highest_score': 129,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 11178740,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 125318},
#     {'chip_name': 'freehit', 'num_played': 41076},
#     {'chip_name': 'wildcard', 'num_played': 202189},
#     {'chip_name': '3xc', 'num_played': 145561}],
#    'most_selected': 328,
#    'most_transferred_in': 71,
#    'top_element': 74,
#    'top_element_info': {'id': 74, 'points': 21},
#    'transfers_made': 10475856,
#    'most_captained': 328,
#    'most_vice_captained': 401},
#   {'id': 24,
#    'name': 'Gameweek 24',
#    'deadline_time': '2025-02-01T11:00:00Z',
#    'release_time': None,
#    'average_entry_score': 87,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 5428593,
#    'deadline_time_epoch': 1738407600,
#    'deadline_time_game_offset': 0,
#    'highest_score': 201,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 11216322,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 111461},
#     {'chip_name': 'freehit', 'num_played': 123991},
#     {'chip_name': 'wildcard', 'num_played': 129674},
#     {'chip_name': '3xc', 'num_played': 1139007},
#     {'chip_name': 'manager', 'num_played': 1177726}],
#    'most_selected': 328,
#    'most_transferred_in': 321,
#    'top_element': 328,
#    'top_element_info': {'id': 328, 'points': 29},
#    'transfers_made': 11002861,
#    'most_captained': 328,
#    'most_vice_captained': 401},
#   {'id': 25,
#    'name': 'Gameweek 25',
#    'deadline_time': '2025-02-14T18:30:00Z',
#    'release_time': None,
#    'average_entry_score': 74,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 2065637,
#    'deadline_time_epoch': 1739557800,
#    'deadline_time_game_offset': 0,
#    'highest_score': 155,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 11262176,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 82673},
#     {'chip_name': 'freehit', 'num_played': 92674},
#     {'chip_name': 'wildcard', 'num_played': 127582},
#     {'chip_name': '3xc', 'num_played': 636104},
#     {'chip_name': 'manager', 'num_played': 901391}],
#    'most_selected': 328,
#    'most_transferred_in': 71,
#    'top_element': 328,
#    'top_element_info': {'id': 328, 'points': 20},
#    'transfers_made': 11066698,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 26,
#    'name': 'Gameweek 26',
#    'deadline_time': '2025-02-21T18:30:00Z',
#    'release_time': None,
#    'average_entry_score': 62,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 1546737,
#    'deadline_time_epoch': 1740162600,
#    'deadline_time_game_offset': 0,
#    'highest_score': 140,
#    'is_previous': True,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 11285417,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 54221},
#     {'chip_name': 'freehit', 'num_played': 28439},
#     {'chip_name': 'wildcard', 'num_played': 103756},
#     {'chip_name': '3xc', 'num_played': 18604},
#     {'chip_name': 'manager', 'num_played': 390248}],
#    'most_selected': 328,
#    'most_transferred_in': 71,
#    'top_element': 762,
#    'top_element_info': {'id': 762, 'points': 15},
#    'transfers_made': 8907059,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 27,
#    'name': 'Gameweek 27',
#    'deadline_time': '2025-02-25T18:00:00Z',
#    'release_time': None,
#    'average_entry_score': 53,
#    'finished': True,
#    'data_checked': True,
#    'highest_scoring_entry': 10980207,
#    'deadline_time_epoch': 1740506400,
#    'deadline_time_game_offset': 0,
#    'highest_score': 120,
#    'is_previous': False,
#    'is_current': True,
#    'is_next': False,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 11301288,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [{'chip_name': 'bboost', 'num_played': 48902},
#     {'chip_name': 'freehit', 'num_played': 29345},
#     {'chip_name': 'wildcard', 'num_played': 104007},
#     {'chip_name': '3xc', 'num_played': 23870},
#     {'chip_name': 'manager', 'num_played': 352459}],
#    'most_selected': 328,
#    'most_transferred_in': 541,
#    'top_element': 163,
#    'top_element_info': {'id': 163, 'points': 15},
#    'transfers_made': 7849779,
#    'most_captained': 328,
#    'most_vice_captained': 182},
#   {'id': 28,
#    'name': 'Gameweek 28',
#    'deadline_time': '2025-03-08T11:00:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1741431600,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': True,
#    'cup_leagues_created': True,
#    'h2h_ko_matches_created': True,
#    'can_enter': True,
#    'can_manage': True,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None},
#   {'id': 29,
#    'name': 'Gameweek 29',
#    'deadline_time': '2025-03-15T13:30:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1742045400,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None},
#   {'id': 30,
#    'name': 'Gameweek 30',
#    'deadline_time': '2025-04-01T17:15:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1743527700,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None},
#   {'id': 31,
#    'name': 'Gameweek 31',
#    'deadline_time': '2025-04-05T10:00:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1743847200,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None},
#   {'id': 32,
#    'name': 'Gameweek 32',
#    'deadline_time': '2025-04-12T10:00:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1744452000,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None},
#   {'id': 33,
#    'name': 'Gameweek 33',
#    'deadline_time': '2025-04-19T12:30:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1745065800,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None},
#   {'id': 34,
#    'name': 'Gameweek 34',
#    'deadline_time': '2025-04-26T10:00:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1745661600,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None},
#   {'id': 35,
#    'name': 'Gameweek 35',
#    'deadline_time': '2025-05-03T12:30:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1746275400,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None},
#   {'id': 36,
#    'name': 'Gameweek 36',
#    'deadline_time': '2025-05-10T12:30:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1746880200,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None},
#   {'id': 37,
#    'name': 'Gameweek 37',
#    'deadline_time': '2025-05-18T12:30:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1747571400,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None},
#   {'id': 38,
#    'name': 'Gameweek 38',
#    'deadline_time': '2025-05-25T13:30:00Z',
#    'release_time': None,
#    'average_entry_score': 0,
#    'finished': False,
#    'data_checked': False,
#    'highest_scoring_entry': None,
#    'deadline_time_epoch': 1748179800,
#    'deadline_time_game_offset': 0,
#    'highest_score': None,
#    'is_previous': False,
#    'is_current': False,
#    'is_next': False,
#    'cup_leagues_created': False,
#    'h2h_ko_matches_created': False,
#    'can_enter': False,
#    'can_manage': False,
#    'released': True,
#    'ranked_count': 0,
#    'overrides': {'rules': {},
#     'scoring': {},
#     'element_types': [],
#     'pick_multiplier': None},
#    'chip_plays': [],
#    'most_selected': None,
#    'most_transferred_in': None,
#    'top_element': None,
#    'top_element_info': None,
#    'transfers_made': 0,
#    'most_captained': None,
#    'most_vice_captained': None}],
#  'game_settings': {'league_join_private_max': 30,
#   'league_join_public_max': 5,
#   'league_max_size_public_classic': 20,
#   'league_max_size_public_h2h': 16,
#   'league_max_size_private_h2h': 16,
#   'league_max_ko_rounds_private_h2h': 3,
#   'league_prefix_public': 'League',
#   'league_points_h2h_win': 3,
#   'league_points_h2h_lose': 0,
#   'league_points_h2h_draw': 1,
#   'league_ko_first_instead_of_random': False,
#   'cup_start_event_id': None,
#   'cup_stop_event_id': None,
#   'cup_qualifying_method': None,
#   'cup_type': None,
#   'featured_entries': [],
#   'element_sell_at_purchase_price': False,
#   'percentile_ranks': [1,
#    5,
#    10,
#    15,
#    20,
#    25,
#    30,
#    35,
#    40,
#    45,
#    50,
#    55,
#    60,
#    65,
#    70,
#    75,
#    80,
#    95,
#    90,
#    95],
#   'underdog_differential': 5,
#   'squad_squadplay': 11,
#   'squad_squadsize': 15,
#   'squad_special_min': None,
#   'squad_special_max': None,
#   'squad_team_limit': 3,
#   'squad_total_spend': 1000,
#   'ui_currency_multiplier': 10,
#   'ui_use_special_shirts': False,
#   'ui_special_shirt_exclusions': [],
#   'stats_form_days': 30,
#   'sys_vice_captain_enabled': True,
#   'transfers_cap': 20,
#   'transfers_sell_on_fee': 0.5,
#   'max_extra_free_transfers': 4,
#   'league_h2h_tiebreak_stats': ['+goals_scored', '-goals_conceded'],
#   'timezone': 'UTC'},
#  'game_config': {'settings': {'entry_per_event': False, 'timezone': 'UTC'},
#   'rules': {'league_join_private_max': 30,
#    'league_join_public_max': 5,
#    'league_max_size_public_classic': 20,
#    'league_max_size_public_h2h': 16,
#    'league_max_size_private_h2h': 16,
#    'league_max_ko_rounds_private_h2h': 3,
#    'league_prefix_public': 'League',
#    'league_points_h2h_win': 3,
#    'league_points_h2h_lose': 0,
#    'league_points_h2h_draw': 1,
#    'league_ko_first_instead_of_random': False,
#    'cup_start_event_id': None,
#    'cup_stop_event_id': None,
#    'cup_qualifying_method': None,
#    'cup_type': None,
#    'featured_entries': [],
#    'element_sell_at_purchase_price': False,
#    'percentile_ranks': [1,
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55,
#     60,
#     65,
#     70,
#     75,
#     80,
#     95,
#     90,
#     95],
#    'underdog_differential': 5,
#    'squad_squadplay': 11,
#    'squad_squadsize': 15,
#    'squad_special_min': None,
#    'squad_special_max': None,
#    'squad_team_limit': 3,
#    'squad_total_spend': 1000,
#    'ui_currency_multiplier': 10,
#    'ui_use_special_shirts': False,
#    'ui_special_shirt_exclusions': [],
#    'stats_form_days': 30,
#    'sys_vice_captain_enabled': True,
#    'transfers_cap': 20,
#    'transfers_sell_on_fee': 0.5,
#    'max_extra_free_transfers': 4,
#    'league_h2h_tiebreak_stats': ['+goals_scored', '-goals_conceded']},
#   'scoring': {'long_play': 2,
#    'short_play': 1,
#    'goals_conceded': {'DEF': -1, 'FWD': 0, 'GKP': -1, 'MID': 0, 'MNG': 0},
#    'saves': 1,
#    'goals_scored': {'DEF': 6, 'FWD': 4, 'GKP': 10, 'MID': 5, 'MNG': 0},
#    'assists': 3,
#    'clean_sheets': {'DEF': 4, 'FWD': 0, 'GKP': 4, 'MID': 1, 'MNG': 0},
#    'penalties_saved': 5,
#    'penalties_missed': -2,
#    'yellow_cards': -1,
#    'red_cards': -3,
#    'own_goals': -2,
#    'bonus': 1,
#    'bps': 0,
#    'influence': 0,
#    'creativity': 0,
#    'threat': 0,
#    'ict_index': 0,
#    'special_multiplier': 1,
#    'mng_goals_scored': {'DEF': 0, 'FWD': 0, 'GKP': 0, 'MID': 0, 'MNG': 1},
#    'mng_clean_sheets': {'DEF': 0, 'FWD': 0, 'GKP': 0, 'MID': 0, 'MNG': 2},
#    'mng_win': {'DEF': 0, 'FWD': 0, 'GKP': 0, 'MID': 0, 'MNG': 6},
#    'mng_draw': {'DEF': 0, 'FWD': 0, 'GKP': 0, 'MID': 0, 'MNG': 3},
#    'mng_loss': 0,
#    'mng_underdog_win': {'DEF': 0, 'FWD': 0, 'GKP': 0, 'MID': 0, 'MNG': 10},
#    'mng_underdog_draw': {'DEF': 0, 'FWD': 0, 'GKP': 0, 'MID': 0, 'MNG': 5}}},
#  'phases': [{'id': 1,
#    'name': 'Overall',
#    'start_event': 1,
#    'stop_event': 38,
#    'highest_score': 2064},
#   {'id': 2,
#    'name': 'August',
#    'start_event': 1,
#    'stop_event': 3,
#    'highest_score': 309},
#   {'id': 3,
#    'name': 'September',
#    'start_event': 4,
#    'stop_event': 6,
#    'highest_score': 301},
#   {'id': 4,
#    'name': 'October',
#    'start_event': 7,
#    'stop_event': 9,
#    'highest_score': 267},
#   {'id': 5,
#    'name': 'November',
#    'start_event': 10,
#    'stop_event': 13,
#    'highest_score': 362},
#   {'id': 6,
#    'name': 'December',
#    'start_event': 14,
#    'stop_event': 19,
#    'highest_score': 551},
#   {'id': 7,
#    'name': 'January',
#    'start_event': 20,
#    'stop_event': 23,
#    'highest_score': 399},
#   {'id': 8,
#    'name': 'February',
#    'start_event': 24,
#    'stop_event': 27,
#    'highest_score': 467},
#   {'id': 9,
#    'name': 'March',
#    'start_event': 28,
#    'stop_event': 29,
#    'highest_score': None},
#   {'id': 10,
#    'name': 'April',
#    'start_event': 30,
#    'stop_event': 34,
#    'highest_score': None},
#   {'id': 11,
#    'name': 'May',
#    'start_event': 35,
#    'stop_event': 38,
#    'highest_score': None}],
#  'teams': [{'code': 3,
#    'draw': 0,
#    'form': None,
#    'id': 1,
#    'loss': 0,
#    'name': 'Arsenal',
#    'played': 0,
#    'points': 0,
#    'position': 2,
#    'short_name': 'ARS',
#    'strength': 4,
#    'team_division': None,
#    'unavailable': False,
#    'win': 0,
#    'strength_overall_home': 1235,
#    'strength_overall_away': 1335,
#    'strength_attack_home': 1220,
#    'strength_attack_away': 1370,
#    'strength_defence_home': 1250,
#    'strength_defence_away': 1300,
#    'pulse_id': 1},
#   {'code': 7,
#    'draw': 0,
#    'form': None,
#    'id': 2,
#    'loss': 0,
#    'name': 'Aston Villa',
#    'played': 0,
#    'points': 0,
#    'position': 10,
#    'short_name': 'AVL',
#    'strength': 3,
#    'team_division': None,
#    'unavailable': False,
#    'win': 0,
#    'strength_overall_home': 1110,
#    'strength_overall_away': 1215,
#    'strength_attack_home': 1080,
#    'strength_attack_away': 1160,
#    'strength_defence_home': 1140,
#    'strength_defence_away': 1270,
#    'pulse_id': 2},
#   {'code': 91,
#    'draw': 0,
#    'form': None,
#    'id': 3,
#    'loss': 0,
#    'name': 'Bournemouth',
#    'played': 0,
#    'points': 0,
#    'position': 7,
#    'short_name': 'BOU',
#    'strength': 4,
#    'team_division': None,
#    'unavailable': False,
#    'win': 0,
#    'strength_overall_home': 1195,
#    'strength_overall_away': 1215,
#    'strength_attack_home': 1130,
#    'strength_attack_away': 1170,
#    'strength_defence_home': 1260,
#    'strength_defence_away': 1260,
#    'pulse_id': 127},
#   {'code': 94,
#    'draw': 0,
#    'form': None,
#    'id': 4,
#    'loss': 0,
#    'name': 'Brentford',
#    'played': 0,
#    'points': 0,
#    'position': 11,
#    'short_name': 'BRE',
#    'strength': 3,
#    'team_division': None,
#    'unavailable': False,
#    'win': 0,
#    'strength_overall_home': 1100,
#    'strength_overall_away': 1195,
#    'strength_attack_home': 1080,
#    'strength_attack_away': 1080,
#    'strength_defence_home': 1120,
#    'strength_defence_away': 1310,
#    'pulse_id': 130},
#   {'code': 36,
#    'draw': 0,
#    'form': None,
#    'id': 5,
#    'loss': 0,
#    'name': 'Brighton',
#    'played': 0,
#    'points': 0,
#    'position': 8,
#    'short_name': 'BHA',
#    'strength': 3,
#    'team_division': None,
#    'unavailable': False,
#    'win': 0,
#    'strength_overall_home': 1140,
#    'strength_overall_away': 1150,
#    'strength_attack_home': 1120,
#    'strength_attack_away': 1140,
#    'strength_defence_home': 1160,
# ...
#    'dreamteam_count': 0,
#    'element_type': 2,
#    'ep_next': '0.0',
#    'ep_this': '0.0',
#    'event_points': 0,
#    'first_name': 'Wes',
#    'form': '0.0',
#    'id': 711,
#    'in_dreamteam': False,
#    'news': '',
#    'news_added': None,
#    'now_cost': 40,
#    'photo': '613467.jpg',
#    'points_per_game': '0.0',
#    'removed': False,
#    'second_name': 'Okoduwa',
#    'selected_by_percent': '0.0',
#    'special': False,
#    'squad_number': None,
#    'status': 'a',
#    'team': 20,
#    'team_code': 39,
#    'total_points': 0,
#    'transfers_in': 1156,
#    'transfers_in_event': 55,
#    'transfers_out': 590,
#    'transfers_out_event': 72,
#    'value_form': '0.0',
#    'value_season': '0.0',
#    'web_name': 'Okoduwa',
#    'region': 241,
#    'team_join_date': '2024-03-02',
#    'birth_date': '2008-05-12',
#    'has_temporary_code': False,
#    'opta_code': 'p613467',
#    'minutes': 0,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 0,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00',
#    'mng_win': 0,
#    'mng_draw': 0,
#    'mng_loss': 0,
#    'mng_underdog_win': 0,
#    'mng_underdog_draw': 0,
#    'mng_clean_sheets': 0,
#    'mng_goals_scored': 0,
#    'influence_rank': 629,
#    'influence_rank_type': 236,
#    'creativity_rank': 613,
#    'creativity_rank_type': 236,
#    'threat_rank': 580,
#    'threat_rank_type': 227,
#    'ict_index_rank': 629,
#    'ict_index_rank_type': 236,
#    'corners_and_indirect_freekicks_order': None,
#    'corners_and_indirect_freekicks_text': '',
#    'direct_freekicks_order': None,
#    'direct_freekicks_text': '',
#    'penalties_order': None,
#    'penalties_text': '',
#    'expected_goals_per_90': 0,
#    'saves_per_90': 0,
#    'expected_assists_per_90': 0,
#    'expected_goal_involvements_per_90': 0,
#    'expected_goals_conceded_per_90': 0,
#    'goals_conceded_per_90': 0,
#    'now_cost_rank': 715,
#    'now_cost_rank_type': 227,
#    'form_rank': 494,
#    'form_rank_type': 193,
#    'points_per_game_rank': 634,
#    'points_per_game_rank_type': 234,
#    'selected_rank': 684,
#    'selected_rank_type': 231,
#    'starts_per_90': 0,
#    'clean_sheets_per_90': 0},
#   {'can_transact': True,
#    'can_select': True,
#    'chance_of_playing_next_round': 0,
#    'chance_of_playing_this_round': 0,
#    'code': 516939,
#    'cost_change_event': 0,
#    'cost_change_event_fall': 0,
#    'cost_change_start': 0,
#    'cost_change_start_fall': 0,
#    'dreamteam_count': 0,
#    'element_type': 2,
#    'ep_next': '0.0',
#    'ep_this': '0.0',
#    'event_points': 0,
#    'first_name': 'Emmanuel',
#    'form': '0.0',
#    'id': 720,
#    'in_dreamteam': False,
#    'news': 'Muscle injury - Unknown return date',
#    'news_added': '2025-02-17T10:00:10.280621Z',
#    'now_cost': 40,
#    'photo': '516939.jpg',
#    'points_per_game': '1.8',
#    'removed': False,
#    'second_name': 'Agbadou',
#    'selected_by_percent': '0.1',
#    'special': False,
#    'squad_number': None,
#    'status': 'i',
#    'team': 20,
#    'team_code': 39,
#    'total_points': 9,
#    'transfers_in': 11756,
#    'transfers_in_event': 60,
#    'transfers_out': 4750,
#    'transfers_out_event': 883,
#    'value_form': '0.0',
#    'value_season': '2.2',
#    'web_name': 'Agbadou',
#    'region': 54,
#    'team_join_date': '2025-01-09',
#    'birth_date': '1997-06-17',
#    'has_temporary_code': False,
#    'opta_code': 'p516939',
#    'minutes': 420,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 1,
#    'goals_conceded': 9,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 2,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 54,
#    'influence': '110.6',
#    'creativity': '4.4',
#    'threat': '14.0',
#    'ict_index': '12.9',
#    'starts': 5,
#    'expected_goals': '0.03',
#    'expected_assists': '0.03',
#    'expected_goal_involvements': '0.06',
#    'expected_goals_conceded': '8.37',
#    'mng_win': 0,
#    'mng_draw': 0,
#    'mng_loss': 0,
#    'mng_underdog_win': 0,
#    'mng_underdog_draw': 0,
#    'mng_clean_sheets': 0,
#    'mng_goals_scored': 0,
#    'influence_rank': 337,
#    'influence_rank_type': 123,
#    'creativity_rank': 453,
#    'creativity_rank_type': 161,
#    'threat_rank': 387,
#    'threat_rank_type': 133,
#    'ict_index_rank': 390,
#    'ict_index_rank_type': 131,
#    'corners_and_indirect_freekicks_order': None,
#    'corners_and_indirect_freekicks_text': '',
#    'direct_freekicks_order': None,
#    'direct_freekicks_text': '',
#    'penalties_order': None,
#    'penalties_text': '',
#    'expected_goals_per_90': 0.01,
#    'saves_per_90': 0.0,
#    'expected_assists_per_90': 0.01,
#    'expected_goal_involvements_per_90': 0.02,
#    'expected_goals_conceded_per_90': 1.79,
#    'goals_conceded_per_90': 1.93,
#    'now_cost_rank': 683,
#    'now_cost_rank_type': 199,
#    'form_rank': 464,
#    'form_rank_type': 167,
#    'points_per_game_rank': 307,
#    'points_per_game_rank_type': 100,
#    'selected_rank': 510,
#    'selected_rank_type': 174,
#    'starts_per_90': 1.07,
#    'clean_sheets_per_90': 0.21},
#   {'can_transact': True,
#    'can_select': True,
#    'chance_of_playing_next_round': None,
#    'chance_of_playing_this_round': None,
#    'code': 100040854,
#    'cost_change_event': 0,
#    'cost_change_event_fall': 0,
#    'cost_change_start': 0,
#    'cost_change_start_fall': 0,
#    'dreamteam_count': 0,
#    'element_type': 5,
#    'ep_next': '7.0',
#    'ep_this': '7.0',
#    'event_points': 1,
#    'first_name': 'Vítor Manuel',
#    'form': '7.0',
#    'id': 751,
#    'in_dreamteam': False,
#    'news': '',
#    'news_added': None,
#    'now_cost': 8,
#    'photo': '100040854.jpg',
#    'points_per_game': '0.0',
#    'removed': False,
#    'second_name': 'de Oliveira Lopes Pereira',
#    'selected_by_percent': '5.9',
#    'special': False,
#    'squad_number': None,
#    'status': 'a',
#    'team': 20,
#    'team_code': 39,
#    'total_points': 41,
#    'transfers_in': 56380,
#    'transfers_in_event': 1291,
#    'transfers_out': 11316,
#    'transfers_out_event': 8527,
#    'value_form': '8.7',
#    'value_season': '51.2',
#    'web_name': 'Pereira',
#    'region': 173,
#    'team_join_date': '2024-12-19',
#    'birth_date': '1968-07-26',
#    'has_temporary_code': False,
#    'opta_code': 'man40855',
#    'minutes': 0,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 0,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00',
#    'mng_win': 2,
#    'mng_draw': 0,
#    'mng_loss': 3,
#    'mng_underdog_win': 2,
#    'mng_underdog_draw': 0,
#    'mng_clean_sheets': 2,
#    'mng_goals_scored': 5,
#    'influence_rank': 534,
#    'influence_rank_type': 7,
#    'creativity_rank': 511,
#    'creativity_rank_type': 7,
#    'threat_rank': 469,
#    'threat_rank_type': 7,
#    'ict_index_rank': 534,
#    'ict_index_rank_type': 7,
#    'corners_and_indirect_freekicks_order': None,
#    'corners_and_indirect_freekicks_text': '',
#    'direct_freekicks_order': None,
#    'direct_freekicks_text': '',
#    'penalties_order': None,
#    'penalties_text': '',
#    'expected_goals_per_90': 0,
#    'saves_per_90': 0,
#    'expected_assists_per_90': 0,
#    'expected_goal_involvements_per_90': 0,
#    'expected_goals_conceded_per_90': 0,
#    'goals_conceded_per_90': 0,
#    'now_cost_rank': 777,
#    'now_cost_rank_type': 12,
#    'form_rank': 12,
#    'form_rank_type': 7,
#    'points_per_game_rank': 540,
#    'points_per_game_rank_type': 7,
#    'selected_rank': 276,
#    'selected_rank_type': 6,
#    'starts_per_90': 0,
#    'clean_sheets_per_90': 0},
#   {'can_transact': True,
#    'can_select': True,
#    'chance_of_playing_next_round': None,
#    'chance_of_playing_this_round': None,
#    'code': 531170,
#    'cost_change_event': 0,
#    'cost_change_event_fall': 0,
#    'cost_change_start': 0,
#    'cost_change_start_fall': 0,
#    'dreamteam_count': 0,
#    'element_type': 2,
#    'ep_next': '0.3',
#    'ep_this': '0.3',
#    'event_points': 0,
#    'first_name': 'Nasser',
#    'form': '0.3',
#    'id': 769,
#    'in_dreamteam': False,
#    'news': '',
#    'news_added': None,
#    'now_cost': 45,
#    'photo': '531170.jpg',
#    'points_per_game': '1.0',
#    'removed': False,
#    'second_name': 'Djiga',
#    'selected_by_percent': '0.0',
#    'special': False,
#    'squad_number': None,
#    'status': 'a',
#    'team': 20,
#    'team_code': 39,
#    'total_points': 1,
#    'transfers_in': 540,
#    'transfers_in_event': 78,
#    'transfers_out': 204,
#    'transfers_out_event': 79,
#    'value_form': '0.1',
#    'value_season': '0.2',
#    'web_name': 'Djiga',
#    'region': 35,
#    'team_join_date': '2025-02-03',
#    'birth_date': '2002-11-15',
#    'has_temporary_code': False,
#    'opta_code': 'p531170',
#    'minutes': 17,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 2,
#    'influence': '2.6',
#    'creativity': '1.2',
#    'threat': '0.0',
#    'ict_index': '0.4',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.06',
#    'mng_win': 0,
#    'mng_draw': 0,
#    'mng_loss': 0,
#    'mng_underdog_win': 0,
#    'mng_underdog_draw': 0,
#    'mng_clean_sheets': 0,
#    'mng_goals_scored': 0,
#    'influence_rank': 512,
#    'influence_rank_type': 180,
#    'creativity_rank': 473,
#    'creativity_rank_type': 174,
#    'threat_rank': 692,
#    'threat_rank_type': 255,
#    'ict_index_rank': 516,
#    'ict_index_rank_type': 181,
#    'corners_and_indirect_freekicks_order': None,
#    'corners_and_indirect_freekicks_text': '',
#    'direct_freekicks_order': None,
#    'direct_freekicks_text': '',
#    'penalties_order': None,
#    'penalties_text': '',
#    'expected_goals_per_90': 0.0,
#    'saves_per_90': 0.0,
#    'expected_assists_per_90': 0.0,
#    'expected_goal_involvements_per_90': 0.0,
#    'expected_goals_conceded_per_90': 0.32,
#    'goals_conceded_per_90': 0.0,
#    'now_cost_rank': 442,
#    'now_cost_rank_type': 75,
#    'form_rank': 350,
#    'form_rank_type': 120,
#    'points_per_game_rank': 469,
#    'points_per_game_rank_type': 164,
#    'selected_rank': 725,
#    'selected_rank_type': 245,
#    'starts_per_90': 0.0,
#    'clean_sheets_per_90': 0.0},
#   {'can_transact': True,
#    'can_select': True,
#    'chance_of_playing_next_round': None,
#    'chance_of_playing_this_round': None,
#    'code': 433312,
#    'cost_change_event': 0,
#    'cost_change_event_fall': 0,
#    'cost_change_start': 0,
#    'cost_change_start_fall': 0,
#    'dreamteam_count': 0,
#    'element_type': 3,
#    'ep_next': '3.0',
#    'ep_this': '3.0',
#    'event_points': 2,
#    'first_name': 'Marshall',
#    'form': '3.0',
#    'id': 770,
#    'in_dreamteam': False,
#    'news': '',
#    'news_added': None,
#    'now_cost': 50,
#    'photo': '433312.jpg',
#    'points_per_game': '3.0',
#    'removed': False,
#    'second_name': 'Munetsi',
#    'selected_by_percent': '0.0',
#    'special': False,
#    'squad_number': None,
#    'status': 'a',
#    'team': 20,
#    'team_code': 39,
#    'total_points': 9,
#    'transfers_in': 3219,
#    'transfers_in_event': 540,
#    'transfers_out': 446,
#    'transfers_out_event': 241,
#    'value_form': '0.6',
#    'value_season': '1.8',
#    'web_name': 'Munetsi',
#    'region': 239,
#    'team_join_date': '2025-02-03',
#    'birth_date': '1996-06-22',
#    'has_temporary_code': False,
#    'opta_code': 'p433312',
#    'minutes': 225,
#    'goals_scored': 0,
#    'assists': 1,
#    'clean_sheets': 1,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 25,
#    'influence': '39.0',
#    'creativity': '26.7',
#    'threat': '42.0',
#    'ict_index': '10.8',
#    'starts': 2,
#    'expected_goals': '1.53',
#    'expected_assists': '0.02',
#    'expected_goal_involvements': '1.54',
#    'expected_goals_conceded': '2.31',
#    'mng_win': 0,
#    'mng_draw': 0,
#    'mng_loss': 0,
#    'mng_underdog_win': 0,
#    'mng_underdog_draw': 0,
#    'mng_clean_sheets': 0,
#    'mng_goals_scored': 0,
#    'influence_rank': 414,
#    'influence_rank_type': 187,
#    'creativity_rank': 377,
#    'creativity_rank_type': 206,
#    'threat_rank': 308,
#    'threat_rank_type': 169,
#    'ict_index_rank': 402,
#    'ict_index_rank_type': 196,
#    'corners_and_indirect_freekicks_order': None,
#    'corners_and_indirect_freekicks_text': '',
#    'direct_freekicks_order': None,
#    'direct_freekicks_text': '',
#    'penalties_order': None,
#    'penalties_text': '',
#    'expected_goals_per_90': 0.61,
#    'saves_per_90': 0.0,
#    'expected_assists_per_90': 0.01,
#    'expected_goal_involvements_per_90': 0.62,
#    'expected_goals_conceded_per_90': 0.92,
#    'goals_conceded_per_90': 0.8,
#    'now_cost_rank': 217,
#    'now_cost_rank_type': 138,
#    'form_rank': 130,
#    'form_rank_type': 51,
#    'points_per_game_rank': 134,
#    'points_per_game_rank_type': 56,
#    'selected_rank': 618,
#    'selected_rank_type': 245,
#    'starts_per_90': 0.8,
#    'clean_sheets_per_90': 0.4},
#   {'can_transact': True,
#    'can_select': True,
#    'chance_of_playing_next_round': None,
#    'chance_of_playing_this_round': None,
#    'code': 647671,
#    'cost_change_event': 0,
#    'cost_change_event_fall': 0,
#    'cost_change_start': 0,
#    'cost_change_start_fall': 0,
#    'dreamteam_count': 0,
#    'element_type': 4,
#    'ep_next': '1.1',
#    'ep_this': '1.1',
#    'event_points': 0,
#    'first_name': 'Mateus',
#    'form': '0.0',
#    'id': 784,
#    'in_dreamteam': False,
#    'news': '',
#    'news_added': None,
#    'now_cost': 45,
#    'photo': '647671.jpg',
#    'points_per_game': '0.0',
#    'removed': False,
#    'second_name': 'Mané',
#    'selected_by_percent': '0.0',
#    'special': False,
#    'squad_number': None,
#    'status': 'a',
#    'team': 20,
#    'team_code': 39,
#    'total_points': 0,
#    'transfers_in': 1039,
#    'transfers_in_event': 1039,
#    'transfers_out': 116,
#    'transfers_out_event': 116,
#    'value_form': '0.0',
#    'value_season': '0.0',
#    'web_name': 'Mané',
#    'region': 241,
#    'team_join_date': '2025-02-24',
#    'birth_date': '2007-09-16',
#    'has_temporary_code': False,
#    'opta_code': 'p647671',
#    'minutes': 0,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 0,
#    'influence': '0.0',
#    'creativity': '0.0',
#    'threat': '0.0',
#    'ict_index': '0.0',
#    'starts': 0,
#    'expected_goals': '0.00',
#    'expected_assists': '0.00',
#    'expected_goal_involvements': '0.00',
#    'expected_goals_conceded': '0.00',
#    'mng_win': 0,
#    'mng_draw': 0,
#    'mng_loss': 0,
#    'mng_underdog_win': 0,
#    'mng_underdog_draw': 0,
#    'mng_clean_sheets': 0,
#    'mng_goals_scored': 0,
#    'influence_rank': 746,
#    'influence_rank_type': 71,
#    'creativity_rank': 742,
#    'creativity_rank_type': 70,
#    'threat_rank': 730,
#    'threat_rank_type': 71,
#    'ict_index_rank': 746,
#    'ict_index_rank_type': 71,
#    'corners_and_indirect_freekicks_order': None,
#    'corners_and_indirect_freekicks_text': '',
#    'direct_freekicks_order': None,
#    'direct_freekicks_text': '',
#    'penalties_order': None,
#    'penalties_text': '',
#    'expected_goals_per_90': 0,
#    'saves_per_90': 0,
#    'expected_assists_per_90': 0,
#    'expected_goal_involvements_per_90': 0,
#    'expected_goals_conceded_per_90': 0,
#    'goals_conceded_per_90': 0,
#    'now_cost_rank': 488,
#    'now_cost_rank_type': 83,
#    'form_rank': 672,
#    'form_rank_type': 56,
#    'points_per_game_rank': 746,
#    'points_per_game_rank_type': 72,
#    'selected_rank': 694,
#    'selected_rank_type': 82,
#    'starts_per_90': 0,
#    'clean_sheets_per_90': 0}]}

# %%
data.keys()
# Out:
# dict_keys(['chips', 'events', 'game_settings', 'game_config', 'phases', 'teams', 'total_players', 'element_stats', 'element_types', 'elements'])

# %%
for player in data['elements']:
    print(player)
    break
# Out:
# {'can_transact': True, 'can_select': False, 'chance_of_playing_next_round': 0, 'chance_of_playing_this_round': 0, 'code': 438098, 'cost_change_event': 0, 'cost_change_event_fall': 0, 'cost_change_start': -1, 'cost_change_start_fall': 1, 'dreamteam_count': 0, 'element_type': 3, 'ep_next': '0.0', 'ep_this': '0.0', 'event_points': 0, 'first_name': 'Fábio', 'form': '0.0', 'id': 1, 'in_dreamteam': False, 'news': 'Has joined Portuguese side FC Porto on loan for the 2024/25 season', 'news_added': '2024-08-29T11:06:25.241953Z', 'now_cost': 54, 'photo': '438098.jpg', 'points_per_game': '0.0', 'removed': False, 'second_name': 'Ferreira Vieira', 'selected_by_percent': '0.0', 'special': False, 'squad_number': None, 'status': 'u', 'team': 1, 'team_code': 3, 'total_points': 0, 'transfers_in': 439, 'transfers_in_event': 0, 'transfers_out': 2816, 'transfers_out_event': 0, 'value_form': '0.0', 'value_season': '0.0', 'web_name': 'Fábio Vieira', 'region': None, 'team_join_date': None, 'birth_date': None, 'has_temporary_code': False, 'opta_code': 'p438098', 'minutes': 0, 'goals_scored': 0, 'assists': 0, 'clean_sheets': 0, 'goals_conceded': 0, 'own_goals': 0, 'penalties_saved': 0, 'penalties_missed': 0, 'yellow_cards': 0, 'red_cards': 0, 'saves': 0, 'bonus': 0, 'bps': 0, 'influence': '0.0', 'creativity': '0.0', 'threat': '0.0', 'ict_index': '0.0', 'starts': 0, 'expected_goals': '0.00', 'expected_assists': '0.00', 'expected_goal_involvements': '0.00', 'expected_goals_conceded': '0.00', 'mng_win': 0, 'mng_draw': 0, 'mng_loss': 0, 'mng_underdog_win': 0, 'mng_underdog_draw': 0, 'mng_clean_sheets': 0, 'mng_goals_scored': 0, 'influence_rank': 775, 'influence_rank_type': 335, 'creativity_rank': 775, 'creativity_rank_type': 335, 'threat_rank': 772, 'threat_rank_type': 334, 'ict_index_rank': 775, 'ict_index_rank_type': 335, 'corners_and_indirect_freekicks_order': None, 'corners_and_indirect_freekicks_text': '', 'direct_freekicks_order': None, 'direct_freekicks_text': '', 'penalties_order': None, 'penalties_text': '', 'expected_goals_per_90': 0, 'saves_per_90': 0, 'expected_assists_per_90': 0, 'expected_goal_involvements_per_90': 0, 'expected_goals_conceded_per_90': 0, 'goals_conceded_per_90': 0, 'now_cost_rank': 132, 'now_cost_rank_type': 82, 'form_rank': 750, 'form_rank_type': 320, 'points_per_game_rank': 773, 'points_per_game_rank_type': 335, 'selected_rank': 709, 'selected_rank_type': 294, 'starts_per_90': 0, 'clean_sheets_per_90': 0}

# %%
dates = []
for date_ in data['events']:
    _date = stats.get('deadline_time')
    dates.append(_date)

mamax(dates)
# Out:
# '2024-08-16T17:30:00Z'

# %%
for date_ in data['events']:
    print(stats)
# Out:
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}
# {'id': 1, 'name': 'Gameweek 1', 'deadline_time': '2024-08-16T17:30:00Z', 'release_time': None, 'average_entry_score': 57, 'finished': True, 'data_checked': True, 'highest_scoring_entry': 3546234, 'deadline_time_epoch': 1723829400, 'deadline_time_game_offset': 0, 'highest_score': 127, 'is_previous': False, 'is_current': False, 'is_next': False, 'cup_leagues_created': False, 'h2h_ko_matches_created': False, 'can_enter': False, 'can_manage': False, 'released': True, 'ranked_count': 8597356, 'overrides': {'rules': {}, 'scoring': {}, 'element_types': [], 'pick_multiplier': None}, 'chip_plays': [{'chip_name': 'bboost', 'num_played': 144974}, {'chip_name': '3xc', 'num_played': 221430}], 'most_selected': 401, 'most_transferred_in': 27, 'top_element': 328, 'top_element_info': {'id': 328, 'points': 14}, 'transfers_made': 0, 'most_captained': 351, 'most_vice_captained': 351}

# %%
_d

# %%
data['teams']
# Out:
# [{'code': 3,
#   'draw': 0,
#   'form': None,
#   'id': 1,
#   'loss': 0,
#   'name': 'Arsenal',
#   'played': 0,
#   'points': 0,
#   'position': 2,
#   'short_name': 'ARS',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1235,
#   'strength_overall_away': 1335,
#   'strength_attack_home': 1220,
#   'strength_attack_away': 1370,
#   'strength_defence_home': 1250,
#   'strength_defence_away': 1300,
#   'pulse_id': 1},
#  {'code': 7,
#   'draw': 0,
#   'form': None,
#   'id': 2,
#   'loss': 0,
#   'name': 'Aston Villa',
#   'played': 0,
#   'points': 0,
#   'position': 10,
#   'short_name': 'AVL',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1110,
#   'strength_overall_away': 1215,
#   'strength_attack_home': 1080,
#   'strength_attack_away': 1160,
#   'strength_defence_home': 1140,
#   'strength_defence_away': 1270,
#   'pulse_id': 2},
#  {'code': 91,
#   'draw': 0,
#   'form': None,
#   'id': 3,
#   'loss': 0,
#   'name': 'Bournemouth',
#   'played': 0,
#   'points': 0,
#   'position': 7,
#   'short_name': 'BOU',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1195,
#   'strength_overall_away': 1215,
#   'strength_attack_home': 1130,
#   'strength_attack_away': 1170,
#   'strength_defence_home': 1260,
#   'strength_defence_away': 1260,
#   'pulse_id': 127},
#  {'code': 94,
#   'draw': 0,
#   'form': None,
#   'id': 4,
#   'loss': 0,
#   'name': 'Brentford',
#   'played': 0,
#   'points': 0,
#   'position': 11,
#   'short_name': 'BRE',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1100,
#   'strength_overall_away': 1195,
#   'strength_attack_home': 1080,
#   'strength_attack_away': 1080,
#   'strength_defence_home': 1120,
#   'strength_defence_away': 1310,
#   'pulse_id': 130},
#  {'code': 36,
#   'draw': 0,
#   'form': None,
#   'id': 5,
#   'loss': 0,
#   'name': 'Brighton',
#   'played': 0,
#   'points': 0,
#   'position': 8,
#   'short_name': 'BHA',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1140,
#   'strength_overall_away': 1150,
#   'strength_attack_home': 1120,
#   'strength_attack_away': 1140,
#   'strength_defence_home': 1160,
#   'strength_defence_away': 1160,
#   'pulse_id': 131},
#  {'code': 8,
#   'draw': 0,
#   'form': None,
#   'id': 6,
#   'loss': 0,
#   'name': 'Chelsea',
#   'played': 0,
#   'points': 0,
#   'position': 5,
#   'short_name': 'CHE',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1230,
#   'strength_overall_away': 1235,
#   'strength_attack_home': 1150,
#   'strength_attack_away': 1150,
#   'strength_defence_home': 1310,
#   'strength_defence_away': 1320,
#   'pulse_id': 4},
#  {'code': 31,
#   'draw': 0,
#   'form': None,
#   'id': 7,
#   'loss': 0,
#   'name': 'Crystal Palace',
#   'played': 0,
#   'points': 0,
#   'position': 12,
#   'short_name': 'CRY',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1130,
#   'strength_overall_away': 1130,
#   'strength_attack_home': 1140,
#   'strength_attack_away': 1140,
#   'strength_defence_home': 1120,
#   'strength_defence_away': 1120,
#   'pulse_id': 6},
#  {'code': 11,
#   'draw': 0,
#   'form': None,
#   'id': 8,
#   'loss': 0,
#   'name': 'Everton',
#   'played': 0,
#   'points': 0,
#   'position': 16,
#   'short_name': 'EVE',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1095,
#   'strength_overall_away': 1125,
#   'strength_attack_home': 1130,
#   'strength_attack_away': 1140,
#   'strength_defence_home': 1070,
#   'strength_defence_away': 1100,
#   'pulse_id': 7},
#  {'code': 54,
#   'draw': 0,
#   'form': None,
#   'id': 9,
#   'loss': 0,
#   'name': 'Fulham',
#   'played': 0,
#   'points': 0,
#   'position': 9,
#   'short_name': 'FUL',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1150,
#   'strength_overall_away': 1150,
#   'strength_attack_home': 1150,
#   'strength_attack_away': 1150,
#   'strength_defence_home': 1150,
#   'strength_defence_away': 1150,
#   'pulse_id': 34},
#  {'code': 40,
#   'draw': 0,
#   'form': None,
#   'id': 10,
#   'loss': 0,
#   'name': 'Ipswich',
#   'played': 0,
#   'points': 0,
#   'position': 18,
#   'short_name': 'IPS',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1075,
#   'strength_overall_away': 1075,
#   'strength_attack_home': 1070,
#   'strength_attack_away': 1070,
#   'strength_defence_home': 1080,
#   'strength_defence_away': 1080,
#   'pulse_id': 8},
#  {'code': 13,
#   'draw': 0,
#   'form': None,
#   'id': 11,
#   'loss': 0,
#   'name': 'Leicester',
#   'played': 0,
#   'points': 0,
#   'position': 19,
#   'short_name': 'LEI',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1075,
#   'strength_overall_away': 1085,
#   'strength_attack_home': 1060,
#   'strength_attack_away': 1080,
#   'strength_defence_home': 1090,
#   'strength_defence_away': 1090,
#   'pulse_id': 26},
#  {'code': 14,
#   'draw': 0,
#   'form': None,
#   'id': 12,
#   'loss': 0,
#   'name': 'Liverpool',
#   'played': 0,
#   'points': 0,
#   'position': 1,
#   'short_name': 'LIV',
#   'strength': 5,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1355,
#   'strength_overall_away': 1360,
#   'strength_attack_home': 1340,
#   'strength_attack_away': 1350,
#   'strength_defence_home': 1370,
#   'strength_defence_away': 1370,
#   'pulse_id': 10},
#  {'code': 43,
#   'draw': 0,
#   'form': None,
#   'id': 13,
#   'loss': 0,
#   'name': 'Man City',
#   'played': 0,
#   'points': 0,
#   'position': 4,
#   'short_name': 'MCI',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1230,
#   'strength_overall_away': 1250,
#   'strength_attack_home': 1140,
#   'strength_attack_away': 1150,
#   'strength_defence_home': 1320,
#   'strength_defence_away': 1350,
#   'pulse_id': 11},
#  {'code': 1,
#   'draw': 0,
#   'form': None,
#   'id': 14,
#   'loss': 0,
#   'name': 'Man Utd',
#   'played': 0,
#   'points': 0,
#   'position': 14,
#   'short_name': 'MUN',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1115,
#   'strength_overall_away': 1140,
#   'strength_attack_home': 1120,
#   'strength_attack_away': 1120,
#   'strength_defence_home': 1110,
#   'strength_defence_away': 1160,
#   'pulse_id': 12},
#  {'code': 4,
#   'draw': 0,
#   'form': None,
#   'id': 15,
#   'loss': 0,
#   'name': 'Newcastle',
#   'played': 0,
#   'points': 0,
#   'position': 6,
#   'short_name': 'NEW',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1195,
#   'strength_overall_away': 1225,
#   'strength_attack_home': 1140,
#   'strength_attack_away': 1150,
#   'strength_defence_home': 1250,
#   'strength_defence_away': 1300,
#   'pulse_id': 23},
#  {'code': 17,
#   'draw': 0,
#   'form': None,
#   'id': 16,
#   'loss': 0,
#   'name': "Nott'm Forest",
#   'played': 0,
#   'points': 0,
#   'position': 3,
#   'short_name': 'NFO',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1195,
#   'strength_overall_away': 1220,
#   'strength_attack_home': 1200,
#   'strength_attack_away': 1250,
#   'strength_defence_home': 1190,
#   'strength_defence_away': 1190,
#   'pulse_id': 15},
#  {'code': 20,
#   'draw': 0,
#   'form': None,
#   'id': 17,
#   'loss': 0,
#   'name': 'Southampton',
#   'played': 0,
#   'points': 0,
#   'position': 20,
#   'short_name': 'SOU',
#   'strength': 2,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1055,
#   'strength_overall_away': 1065,
#   'strength_attack_home': 1050,
#   'strength_attack_away': 1050,
#   'strength_defence_home': 1060,
#   'strength_defence_away': 1080,
#   'pulse_id': 20},
#  {'code': 6,
#   'draw': 0,
#   'form': None,
#   'id': 18,
#   'loss': 0,
#   'name': 'Spurs',
#   'played': 0,
#   'points': 0,
#   'position': 13,
#   'short_name': 'TOT',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1150,
#   'strength_overall_away': 1185,
#   'strength_attack_home': 1090,
#   'strength_attack_away': 1090,
#   'strength_defence_home': 1210,
#   'strength_defence_away': 1280,
#   'pulse_id': 21},
#  {'code': 21,
#   'draw': 0,
#   'form': None,
#   'id': 19,
#   'loss': 0,
#   'name': 'West Ham',
#   'played': 0,
#   'points': 0,
#   'position': 15,
#   'short_name': 'WHU',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1095,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1080,
#   'strength_attack_away': 1080,
#   'strength_defence_home': 1110,
#   'strength_defence_away': 1120,
#   'pulse_id': 25},
#  {'code': 39,
#   'draw': 0,
#   'form': None,
#   'id': 20,
#   'loss': 0,
#   'name': 'Wolves',
#   'played': 0,
#   'points': 0,
#   'position': 17,
#   'short_name': 'WOL',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1095,
#   'strength_overall_away': 1095,
#   'strength_attack_home': 1070,
#   'strength_attack_away': 1070,
#   'strength_defence_home': 1120,
#   'strength_defence_away': 1120,
#   'pulse_id': 38}]
